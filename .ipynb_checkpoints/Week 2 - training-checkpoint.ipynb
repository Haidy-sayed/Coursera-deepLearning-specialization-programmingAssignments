# %%
import numpy as np
print(np.log(0.9))
# Out:
# -0.10536051565782628

# %%
a=np.random.randn(3,4)
b=np.random.randn(1,4)
c=a+b
print(c)
c.shape
# Out:
# [[ 1.24525182 -2.26550788  2.39983916 -2.44988192]
#  [-0.346401   -0.67869691  1.61696008 -3.03637761]
#  [ 0.21704722 -0.94239845  0.86350828 -1.60641116]]
# (3, 4)

# %%
a=np.random.randn(1,3)
b=np.random.randn(3,3)
c=a*b
print(c)
c.shape
# Out:
# [[ 8.53590604e-01 -1.86229348e+00 -8.10345489e-01]
#  [-1.15791286e+00  7.75959630e-04 -1.03826650e+00]
#  [-6.97477754e-01  1.28601652e+00  5.70178652e-01]]
# (3, 3)

# %%
a=np.array([[2,1],[1,3]])
c=np.dot(a,a)
print(c)
# Out:
# [[ 5  5]
#  [ 5 10]]

# %%
a=np.array([[1,1],[1,-1]])
b=np.array([[2],[3]])
c=a+b
print(c)
# Out:
# [[3 3]
#  [4 2]]

# %%
#some basic functions that are commonly used in deep learning
import numpy as np

#SIGMOID

def sigmoid(x):
    """
    Compute the sigmoid of x

    Arguments:
    x -- A scalar or numpy array of any size

    Return:
    s -- sigmoid(x)
    """
    s=1/(1+np.exp(-x))
    
    return s
#SIGMOID GRADIENT

def sigmoid_gradient(x):
    """
    Compute the gradient (also called the slope or derivative) of the sigmoid function with respect to its input x.
    
    Arguments:
    x -- A scalar or numpy array

    Return:
    ds -- Your computed gradient.
    """
    s=sigmoid(x)
    ds=s*(1-s)
    
    return ds

#IMAGE2VECTOR

def image2vector(image):
    """
    Argument:
    image -- a numpy array of shape (length, height, depth)
    
    Returns:
    v -- a vector of shape (length*height*depth, 1)
    """

    v=image.reshape((image.shape[0]*image.shape[1]*2,1))
    
    return v

#NORMALIZE ROWS
def normalize_rows(x):
    """
    Implementing a function that normalizes each row of the matrix x (to have unit length).
    
    Argument:
    x -- A numpy matrix of shape (n, m)
    
    Returns:
    x -- The normalized (by row) numpy matrix. You are allowed to modify x.
    """
    
    # Compute x_norm as the norm 2 of x. Use np.linalg.norm(..., ord = 2, axis = ..., keepdims = True)
    # x_norm = np.linalg.norm(..., ord = 2, axis = ..., keepdims = True)
    # Divide x by its norm.

    x_norm = np.linalg.norm(x, ord = 2, axis =1, keepdims = True)
    x = x/x_norm

    return x

#SOFT MAX
def softmax(x):
    """Calculates the softmax for each row of the input x.

    Argument:
    x -- A numpy matrix of shape (m,n)

    Returns:
    s -- A numpy matrix equal to the softmax of x, of shape (m,n)
    """
    # Apply exp() element-wise to x. Use np.exp(...).
    x_exp = np.exp(x)
    # Create a vector x_sum that sums each row of x_exp. Use np.sum(..., axis = 1, keepdims = True).
    x_sum = np.sum(x_exp,axis=1,keepdims = True)
    # Compute softmax(x) by dividing x_exp by x_sum. It should automatically use numpy broadcasting.
    s=x_exp/x_sum
    
    return s

# LOSS FUNCTION as L=sum|y(i)-yhat(i)

def L1(yhat, y):
    """
    Arguments:
    yhat -- vector of size m (predicted labels)
    y -- vector of size m (true labels)
    
    Returns:
    loss -- the value of the L1 loss function defined above
    """
    loss=np.sum(np.abs(y-yhat))
    
    return loss
